# %%
import numpy as np 
import pandas as pd
from sklearn.model_selection import RepeatedKFold
import matplotlib.pyplot as plt
import copy
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score, confusion_matrix
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_predict
from tqdm import tqdm
from sklearn.model_selection import StratifiedKFold
import geopandas as gpd
import os
import optuna
import joblib

# %%
import pandas as pd
import os
from sklearn.preprocessing import LabelEncoder

# %%
watershed_attributes_50 = [ 
       'DA_SQKM', 'MAXDI_EROM', 'Dam_Index', 'TOT_ELEV_MEAN', 'TOT_ELEV_MAX',
       'TOT_STREAM_SLOPE', 'TOT_MAXP6190', 'TOT_MAXWD6190', 'TOT_MINWD6190',
       'TOT_RH', 'TOT_AET', 'TOT_CWD', 'TOT_BFI', 'TOT_CONTACT', 'TOT_IEOF',
       'TOT_RECHG', 'TOT_SATOF', 'TOT_TWI', 'TOT_EWT', 'TOT_RF7100',
       'TOT_MIRAD_2012', 'TOT_FRESHWATER_WD', 'TOT_STREAMRIVER',
       'TOT_ARTIFICIAL', 'TOT_CONNECTOR', 'TOT_STRM_DENS',
       'TOT_TOTAL_ROAD_DENS', 'TOT_HGA', 'TOT_HGB', 'TOT_HGC', 'TOT_HGD',
       'TOT_SILTAVE', 'TOT_CLAYAVE', 'TOT_SANDAVE', 'TOT_KFACT',
       'TOT_KFACT_UP', 'TOT_NO10AVE', 'TOT_NO200AVE', 'TOT_OM', 'TOT_ROCKDEP',
       'TOT_BDAVE', 'TOT_WTDEP', 'TOT_SRL25AG', 'TOT_NLCD19_31',
       'TOT_NLCD19_41', 'TOT_NLCD19_43', 'TOT_NLCD19_71', 'TOT_NLCD19_81',
       'TOT_NLCD19_FOREST', 'TOT_NLCD19_WETLAND']

# %%
# Data
# Importing spatial info
all_data = pd.read_csv(os.path.join(os.getcwd(), 'Data','WA_50_Geospatial_PUB_Variable_0d_LSTM_Error_metrics.csv'))
reg_data = all_data[all_data['Dam_Index']>=0.1]
unreg_data = all_data[all_data['Dam_Index']<0.1]

WA_df = all_data[watershed_attributes_50]
WA_df=(WA_df-WA_df.min())/(WA_df.max()-WA_df.min()) # normalizing watershed attributes
WA_arr = WA_df.to_numpy()

# %% [markdown]
# ## hyperparameters optimization

# %%
X = all_data[watershed_attributes_50]  
y = all_data['kge_kappa_categories']
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

def objective(trial):

    # Define the hyperparameters to be tuned
    n_estimators = trial.suggest_int('n_estimators', 200, 500)
    criterion = trial.suggest_categorical('criterion', ['gini', 'entropy', 'log_loss'])
    min_samples_split = trial.suggest_int('min_samples_split', 5, 30)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 5, 20)
    max_features = trial.suggest_categorical('max_features', ['sqrt', 'log2', None])
    max_leaf_nodes = trial.suggest_int('max_leaf_nodes', 2, 100, log=True)
    ccp_alpha = trial.suggest_float('ccp_alpha', 0.00, 0.20)
    
    #class_weight = trial.suggest_categorical('class_weight', [None, 'balanced', 'balanced_subsample'])

    # Create the RandomForestClassifier with the hyperparameters
    clf = RandomForestClassifier(
        n_estimators=n_estimators,
        criterion=criterion,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        max_features=max_features,
        max_leaf_nodes=max_leaf_nodes,
        ccp_alpha=ccp_alpha,
        class_weight =  {1: 1, 0: 2} # 1 is Below median and 0 is Above median
    )

   # Evaluate the classifier using stratified cross-validation
    skf = StratifiedKFold(n_splits=10)
    f1_scores = []
    confusion_matrices = []
    
    for train_index, test_index in skf.split(X, y):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y[train_index], y[test_index]
        
        clf.fit(X_train, y_train)
        y_pred = clf.predict(X_test)
        
        f1_scores.append(f1_score(y_test, y_pred, average='macro'))
        confusion_matrices.append(confusion_matrix(y_test, y_pred))
    
    # Average F1 score
    average_f1_score = np.mean(f1_scores)
    
    return average_f1_score

# Create a study and optimize
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)

print('Number of finished trials:', len(study.trials))
print('Best trial:', study.best_trial.params)
# Out:
# [I 2025-03-27 15:44:43,119] A new study created in memory with name: no-name-362dc042-24aa-4248-bfce-7cc832017eb2
# [I 2025-03-27 15:44:48,492] Trial 0 finished with value: 0.5372892621305893 and parameters: {'n_estimators': 348, 'criterion': 'gini', 'min_samples_split': 19, 'min_samples_leaf': 17, 'max_features': 'log2', 'max_leaf_nodes': 19, 'ccp_alpha': 0.011807465354867763}. Best is trial 0 with value: 0.5372892621305893.
# [I 2025-03-27 15:44:59,344] Trial 1 finished with value: 0.2928136713042373 and parameters: {'n_estimators': 292, 'criterion': 'log_loss', 'min_samples_split': 18, 'min_samples_leaf': 6, 'max_features': None, 'max_leaf_nodes': 2, 'ccp_alpha': 0.1547631888554826}. Best is trial 0 with value: 0.5372892621305893.
# [I 2025-03-27 15:45:32,912] Trial 2 finished with value: 0.5616910375544502 and parameters: {'n_estimators': 445, 'criterion': 'log_loss', 'min_samples_split': 20, 'min_samples_leaf': 5, 'max_features': None, 'max_leaf_nodes': 49, 'ccp_alpha': 0.04638580279006082}. Best is trial 2 with value: 0.5616910375544502.
# [I 2025-03-27 15:45:40,106] Trial 3 finished with value: 0.3181388126199447 and parameters: {'n_estimators': 482, 'criterion': 'gini', 'min_samples_split': 13, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'max_leaf_nodes': 3, 'ccp_alpha': 0.04967596862441053}. Best is trial 2 with value: 0.5616910375544502.
# [I 2025-03-27 15:45:44,341] Trial 4 finished with value: 0.2928136713042373 and parameters: {'n_estimators': 242, 'criterion': 'entropy', 'min_samples_split': 29, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_leaf_nodes': 7, 'ccp_alpha': 0.17060056170688115}. Best is trial 2 with value: 0.5616910375544502.
# [I 2025-03-27 15:46:03,493] Trial 5 finished with value: 0.5173117297676935 and parameters: {'n_estimators': 390, 'criterion': 'entropy', 'min_samples_split': 23, 'min_samples_leaf': 19, 'max_features': None, 'max_leaf_nodes': 23, 'ccp_alpha': 0.08151606081729179}. Best is trial 2 with value: 0.5616910375544502.
# [I 2025-03-27 15:46:11,543] Trial 6 finished with value: 0.31381258959727326 and parameters: {'n_estimators': 452, 'criterion': 'log_loss', 'min_samples_split': 8, 'min_samples_leaf': 18, 'max_features': 'sqrt', 'max_leaf_nodes': 26, 'ccp_alpha': 0.08069818228632344}. Best is trial 2 with value: 0.5616910375544502.
# [I 2025-03-27 15:46:17,784] Trial 7 finished with value: 0.2928136713042373 and parameters: {'n_estimators': 407, 'criterion': 'entropy', 'min_samples_split': 21, 'min_samples_leaf': 11, 'max_features': 'log2', 'max_leaf_nodes': 3, 'ccp_alpha': 0.19217331489016068}. Best is trial 2 with value: 0.5616910375544502.
# [I 2025-03-27 15:46:24,689] Trial 8 finished with value: 0.30699199298255897 and parameters: {'n_estimators': 474, 'criterion': 'gini', 'min_samples_split': 20, 'min_samples_leaf': 20, 'max_features': 'log2', 'max_leaf_nodes': 36, 'ccp_alpha': 0.051690360990738204}. Best is trial 2 with value: 0.5616910375544502.
# [I 2025-03-27 15:46:30,548] Trial 9 finished with value: 0.2928136713042373 and parameters: {'n_estimators': 371, 'criterion': 'gini', 'min_samples_split': 27, 'min_samples_leaf': 7, 'max_features': 'log2', 'max_leaf_nodes': 6, 'ccp_alpha': 0.07705029570226979}. Best is trial 2 with value: 0.5616910375544502.
# [I 2025-03-27 15:46:41,711] Trial 10 finished with value: 0.29641338640395243 and parameters: {'n_estimators': 200, 'criterion': 'log_loss', 'min_samples_split': 13, 'min_samples_leaf': 14, 'max_features': None, 'max_leaf_nodes': 87, 'ccp_alpha': 0.12679874771574004}. Best is trial 2 with value: 0.5616910375544502.
# [I 2025-03-27 15:46:55,333] Trial 11 finished with value: 0.5809070091665236 and parameters: {'n_estimators': 318, 'criterion': 'gini', 'min_samples_split': 14, 'min_samples_leaf': 15, 'max_features': None, 'max_leaf_nodes': 77, 'ccp_alpha': 0.0027796623683868597}. Best is trial 11 with value: 0.5809070091665236.
# [I 2025-03-27 15:47:14,250] Trial 12 finished with value: 0.5792988976761118 and parameters: {'n_estimators': 324, 'criterion': 'log_loss', 'min_samples_split': 13, 'min_samples_leaf': 14, 'max_features': None, 'max_leaf_nodes': 95, 'ccp_alpha': 0.004631095238754344}. Best is trial 11 with value: 0.5809070091665236.
# [I 2025-03-27 15:47:31,591] Trial 13 finished with value: 0.5799629606909393 and parameters: {'n_estimators': 312, 'criterion': 'log_loss', 'min_samples_split': 12, 'min_samples_leaf': 15, 'max_features': None, 'max_leaf_nodes': 95, 'ccp_alpha': 0.000569549096319075}. Best is trial 11 with value: 0.5809070091665236.
# [I 2025-03-27 15:47:43,541] Trial 14 finished with value: 0.5883114024509577 and parameters: {'n_estimators': 291, 'criterion': 'gini', 'min_samples_split': 5, 'min_samples_leaf': 16, 'max_features': None, 'max_leaf_nodes': 61, 'ccp_alpha': 0.02742804090471434}. Best is trial 14 with value: 0.5883114024509577.
# [I 2025-03-27 15:47:54,567] Trial 15 finished with value: 0.5885926749419448 and parameters: {'n_estimators': 275, 'criterion': 'gini', 'min_samples_split': 5, 'min_samples_leaf': 16, 'max_features': None, 'max_leaf_nodes': 56, 'ccp_alpha': 0.030850632255171248}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:48:04,874] Trial 16 finished with value: 0.5544750867001961 and parameters: {'n_estimators': 265, 'criterion': 'gini', 'min_samples_split': 5, 'min_samples_leaf': 17, 'max_features': None, 'max_leaf_nodes': 12, 'ccp_alpha': 0.035880732908819366}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:48:08,988] Trial 17 finished with value: 0.2928136713042373 and parameters: {'n_estimators': 244, 'criterion': 'gini', 'min_samples_split': 5, 'min_samples_leaf': 12, 'max_features': 'sqrt', 'max_leaf_nodes': 49, 'ccp_alpha': 0.10699052423680636}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:48:17,478] Trial 18 finished with value: 0.5614810276175708 and parameters: {'n_estimators': 214, 'criterion': 'gini', 'min_samples_split': 9, 'min_samples_leaf': 16, 'max_features': None, 'max_leaf_nodes': 13, 'ccp_alpha': 0.03282937992798866}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:48:27,876] Trial 19 finished with value: 0.4750401157544014 and parameters: {'n_estimators': 278, 'criterion': 'gini', 'min_samples_split': 9, 'min_samples_leaf': 20, 'max_features': None, 'max_leaf_nodes': 48, 'ccp_alpha': 0.06241891537119668}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:48:31,816] Trial 20 finished with value: 0.53891780486853 and parameters: {'n_estimators': 242, 'criterion': 'gini', 'min_samples_split': 7, 'min_samples_leaf': 13, 'max_features': 'sqrt', 'max_leaf_nodes': 34, 'ccp_alpha': 0.02168250926988566}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:48:44,932] Trial 21 finished with value: 0.587438362611873 and parameters: {'n_estimators': 331, 'criterion': 'gini', 'min_samples_split': 16, 'min_samples_leaf': 16, 'max_features': None, 'max_leaf_nodes': 65, 'ccp_alpha': 0.017797847871439225}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:48:59,116] Trial 22 finished with value: 0.5717314177193951 and parameters: {'n_estimators': 355, 'criterion': 'gini', 'min_samples_split': 16, 'min_samples_leaf': 17, 'max_features': None, 'max_leaf_nodes': 68, 'ccp_alpha': 0.020450164458416006}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:49:10,947] Trial 23 finished with value: 0.5784847801279531 and parameters: {'n_estimators': 297, 'criterion': 'gini', 'min_samples_split': 10, 'min_samples_leaf': 16, 'max_features': None, 'max_leaf_nodes': 54, 'ccp_alpha': 0.02460994335609238}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:49:20,925] Trial 24 finished with value: 0.4683292783155776 and parameters: {'n_estimators': 263, 'criterion': 'gini', 'min_samples_split': 6, 'min_samples_leaf': 18, 'max_features': None, 'max_leaf_nodes': 33, 'ccp_alpha': 0.06350018809415818}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:49:39,102] Trial 25 finished with value: 0.44086576814708056 and parameters: {'n_estimators': 330, 'criterion': 'entropy', 'min_samples_split': 24, 'min_samples_leaf': 13, 'max_features': None, 'max_leaf_nodes': 62, 'ccp_alpha': 0.10097330565403624}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:49:53,245] Trial 26 finished with value: 0.5552372863346049 and parameters: {'n_estimators': 350, 'criterion': 'gini', 'min_samples_split': 16, 'min_samples_leaf': 15, 'max_features': None, 'max_leaf_nodes': 16, 'ccp_alpha': 0.03786007406758712}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:50:07,125] Trial 27 finished with value: 0.2928136713042373 and parameters: {'n_estimators': 295, 'criterion': 'gini', 'min_samples_split': 10, 'min_samples_leaf': 10, 'max_features': None, 'max_leaf_nodes': 34, 'ccp_alpha': 0.1183845157452082}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:50:13,483] Trial 28 finished with value: 0.2928136713042373 and parameters: {'n_estimators': 396, 'criterion': 'gini', 'min_samples_split': 11, 'min_samples_leaf': 18, 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'ccp_alpha': 0.06799342826803054}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:50:27,221] Trial 29 finished with value: 0.5755582008614221 and parameters: {'n_estimators': 338, 'criterion': 'gini', 'min_samples_split': 7, 'min_samples_leaf': 16, 'max_features': None, 'max_leaf_nodes': 20, 'ccp_alpha': 0.018250067486576912}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:50:33,211] Trial 30 finished with value: 0.5416085401312849 and parameters: {'n_estimators': 370, 'criterion': 'entropy', 'min_samples_split': 16, 'min_samples_leaf': 19, 'max_features': 'log2', 'max_leaf_nodes': 42, 'ccp_alpha': 0.0318160439057436}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:50:46,893] Trial 31 finished with value: 0.5714268679935467 and parameters: {'n_estimators': 321, 'criterion': 'gini', 'min_samples_split': 14, 'min_samples_leaf': 15, 'max_features': None, 'max_leaf_nodes': 71, 'ccp_alpha': 0.009035669131463343}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:51:00,011] Trial 32 finished with value: 0.5761985173609894 and parameters: {'n_estimators': 306, 'criterion': 'gini', 'min_samples_split': 18, 'min_samples_leaf': 14, 'max_features': None, 'max_leaf_nodes': 75, 'ccp_alpha': 0.010930217390261093}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:51:11,786] Trial 33 finished with value: 0.5685314015272337 and parameters: {'n_estimators': 284, 'criterion': 'gini', 'min_samples_split': 15, 'min_samples_leaf': 16, 'max_features': None, 'max_leaf_nodes': 58, 'ccp_alpha': 0.004125369830534853}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:51:22,811] Trial 34 finished with value: 0.5146736275191934 and parameters: {'n_estimators': 273, 'criterion': 'gini', 'min_samples_split': 18, 'min_samples_leaf': 17, 'max_features': None, 'max_leaf_nodes': 26, 'ccp_alpha': 0.04726269529588489}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:51:36,883] Trial 35 finished with value: 0.5783391902535946 and parameters: {'n_estimators': 311, 'criterion': 'gini', 'min_samples_split': 7, 'min_samples_leaf': 12, 'max_features': None, 'max_leaf_nodes': 79, 'ccp_alpha': 0.014762932468821903}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:51:46,386] Trial 36 finished with value: 0.5403146617186774 and parameters: {'n_estimators': 227, 'criterion': 'gini', 'min_samples_split': 22, 'min_samples_leaf': 15, 'max_features': None, 'max_leaf_nodes': 43, 'ccp_alpha': 0.04235421032134722}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:52:03,376] Trial 37 finished with value: 0.2928136713042373 and parameters: {'n_estimators': 420, 'criterion': 'gini', 'min_samples_split': 5, 'min_samples_leaf': 17, 'max_features': None, 'max_leaf_nodes': 98, 'ccp_alpha': 0.1444001585773339}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:52:10,415] Trial 38 finished with value: 0.495446844269667 and parameters: {'n_estimators': 368, 'criterion': 'entropy', 'min_samples_split': 11, 'min_samples_leaf': 14, 'max_features': 'sqrt', 'max_leaf_nodes': 57, 'ccp_alpha': 0.05271670344947834}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:52:14,078] Trial 39 finished with value: 0.2928136713042373 and parameters: {'n_estimators': 254, 'criterion': 'log_loss', 'min_samples_split': 25, 'min_samples_leaf': 19, 'max_features': 'log2', 'max_leaf_nodes': 2, 'ccp_alpha': 0.08735605957342307}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:52:30,701] Trial 40 finished with value: 0.5735708634189332 and parameters: {'n_estimators': 294, 'criterion': 'gini', 'min_samples_split': 30, 'min_samples_leaf': 5, 'max_features': None, 'max_leaf_nodes': 28, 'ccp_alpha': 0.028671392856738517}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:52:49,457] Trial 41 finished with value: 0.5796044431883894 and parameters: {'n_estimators': 336, 'criterion': 'log_loss', 'min_samples_split': 13, 'min_samples_leaf': 15, 'max_features': None, 'max_leaf_nodes': 98, 'ccp_alpha': 0.003617219666761691}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:53:07,265] Trial 42 finished with value: 0.5741636413491056 and parameters: {'n_estimators': 324, 'criterion': 'log_loss', 'min_samples_split': 12, 'min_samples_leaf': 16, 'max_features': None, 'max_leaf_nodes': 74, 'ccp_alpha': 0.0019279312732158951}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:53:24,235] Trial 43 finished with value: 0.5699432610357036 and parameters: {'n_estimators': 304, 'criterion': 'log_loss', 'min_samples_split': 20, 'min_samples_leaf': 15, 'max_features': None, 'max_leaf_nodes': 63, 'ccp_alpha': 0.016793292939093485}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:53:41,741] Trial 44 finished with value: 0.5507135123438577 and parameters: {'n_estimators': 314, 'criterion': 'log_loss', 'min_samples_split': 15, 'min_samples_leaf': 13, 'max_features': None, 'max_leaf_nodes': 43, 'ccp_alpha': 0.0005738869911103908}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:53:46,096] Trial 45 finished with value: 0.46528202346777026 and parameters: {'n_estimators': 279, 'criterion': 'log_loss', 'min_samples_split': 17, 'min_samples_leaf': 18, 'max_features': 'log2', 'max_leaf_nodes': 6, 'ccp_alpha': 0.056391435829721066}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:54:05,298] Trial 46 finished with value: 0.2928136713042373 and parameters: {'n_estimators': 360, 'criterion': 'entropy', 'min_samples_split': 8, 'min_samples_leaf': 14, 'max_features': None, 'max_leaf_nodes': 84, 'ccp_alpha': 0.19107305013218223}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:54:28,850] Trial 47 finished with value: 0.5720712714593853 and parameters: {'n_estimators': 384, 'criterion': 'log_loss', 'min_samples_split': 12, 'min_samples_leaf': 10, 'max_features': None, 'max_leaf_nodes': 100, 'ccp_alpha': 0.02857039531571151}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:54:33,043] Trial 48 finished with value: 0.4364593079872 and parameters: {'n_estimators': 266, 'criterion': 'gini', 'min_samples_split': 19, 'min_samples_leaf': 16, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'ccp_alpha': 0.041316232877557674}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:54:46,387] Trial 49 finished with value: 0.57436462560587 and parameters: {'n_estimators': 343, 'criterion': 'gini', 'min_samples_split': 14, 'min_samples_leaf': 17, 'max_features': None, 'max_leaf_nodes': 84, 'ccp_alpha': 0.012408243553405383}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:55:03,051] Trial 50 finished with value: 0.5746528303793593 and parameters: {'n_estimators': 290, 'criterion': 'log_loss', 'min_samples_split': 6, 'min_samples_leaf': 12, 'max_features': None, 'max_leaf_nodes': 40, 'ccp_alpha': 0.022427090789726198}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:55:20,817] Trial 51 finished with value: 0.5751041761743825 and parameters: {'n_estimators': 339, 'criterion': 'log_loss', 'min_samples_split': 13, 'min_samples_leaf': 15, 'max_features': None, 'max_leaf_nodes': 66, 'ccp_alpha': 0.007522387648736341}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:55:38,300] Trial 52 finished with value: 0.5731618410690721 and parameters: {'n_estimators': 333, 'criterion': 'log_loss', 'min_samples_split': 12, 'min_samples_leaf': 15, 'max_features': None, 'max_leaf_nodes': 83, 'ccp_alpha': 0.0011338565253502485}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:55:55,437] Trial 53 finished with value: 0.5587318959816703 and parameters: {'n_estimators': 319, 'criterion': 'log_loss', 'min_samples_split': 9, 'min_samples_leaf': 14, 'max_features': None, 'max_leaf_nodes': 99, 'ccp_alpha': 0.013265414847141848}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:56:12,535] Trial 54 finished with value: 0.5624078670403622 and parameters: {'n_estimators': 304, 'criterion': 'log_loss', 'min_samples_split': 14, 'min_samples_leaf': 13, 'max_features': None, 'max_leaf_nodes': 61, 'ccp_alpha': 0.026960933875258268}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:56:32,195] Trial 55 finished with value: 0.5524281400278807 and parameters: {'n_estimators': 498, 'criterion': 'gini', 'min_samples_split': 17, 'min_samples_leaf': 18, 'max_features': None, 'max_leaf_nodes': 51, 'ccp_alpha': 0.03740296024761334}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:56:36,077] Trial 56 finished with value: 0.48826580610815923 and parameters: {'n_estimators': 250, 'criterion': 'log_loss', 'min_samples_split': 15, 'min_samples_leaf': 16, 'max_features': 'log2', 'max_leaf_nodes': 4, 'ccp_alpha': 0.01946043666649768}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:56:50,494] Trial 57 finished with value: 0.5794867726823953 and parameters: {'n_estimators': 348, 'criterion': 'gini', 'min_samples_split': 10, 'min_samples_leaf': 17, 'max_features': None, 'max_leaf_nodes': 30, 'ccp_alpha': 0.00873936236016439}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:56:54,979] Trial 58 finished with value: 0.41280577478619956 and parameters: {'n_estimators': 228, 'criterion': 'entropy', 'min_samples_split': 8, 'min_samples_leaf': 15, 'max_features': 'sqrt', 'max_leaf_nodes': 86, 'ccp_alpha': 0.07164378748668543}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:57:12,983] Trial 59 finished with value: 0.58520623448774 and parameters: {'n_estimators': 382, 'criterion': 'gini', 'min_samples_split': 6, 'min_samples_leaf': 11, 'max_features': None, 'max_leaf_nodes': 69, 'ccp_alpha': 0.00013966387470119813}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:57:35,629] Trial 60 finished with value: 0.5834594211021363 and parameters: {'n_estimators': 432, 'criterion': 'gini', 'min_samples_split': 6, 'min_samples_leaf': 8, 'max_features': None, 'max_leaf_nodes': 38, 'ccp_alpha': 0.022837979574427417}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:57:59,249] Trial 61 finished with value: 0.571920356903836 and parameters: {'n_estimators': 437, 'criterion': 'gini', 'min_samples_split': 6, 'min_samples_leaf': 7, 'max_features': None, 'max_leaf_nodes': 38, 'ccp_alpha': 0.032802444023899244}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:58:20,547] Trial 62 finished with value: 0.5668772205973525 and parameters: {'n_estimators': 458, 'criterion': 'gini', 'min_samples_split': 5, 'min_samples_leaf': 12, 'max_features': None, 'max_leaf_nodes': 47, 'ccp_alpha': 0.0207033212006022}. Best is trial 15 with value: 0.5885926749419448.
# [I 2025-03-27 15:58:42,455] Trial 63 finished with value: 0.5949376528550827 and parameters: {'n_estimators': 408, 'criterion': 'gini', 'min_samples_split': 7, 'min_samples_leaf': 8, 'max_features': None, 'max_leaf_nodes': 70, 'ccp_alpha': 0.013643252194366098}. Best is trial 63 with value: 0.5949376528550827.
# [I 2025-03-27 15:59:04,520] Trial 64 finished with value: 0.5422270135807463 and parameters: {'n_estimators': 418, 'criterion': 'gini', 'min_samples_split': 7, 'min_samples_leaf': 8, 'max_features': None, 'max_leaf_nodes': 66, 'ccp_alpha': 0.042315247434680056}. Best is trial 63 with value: 0.5949376528550827.
# [I 2025-03-27 15:59:23,349] Trial 65 finished with value: 0.5902281080001102 and parameters: {'n_estimators': 384, 'criterion': 'gini', 'min_samples_split': 6, 'min_samples_leaf': 9, 'max_features': None, 'max_leaf_nodes': 21, 'ccp_alpha': 0.026227266644074557}. Best is trial 63 with value: 0.5949376528550827.
# [I 2025-03-27 15:59:42,212] Trial 66 finished with value: 0.5781126481399994 and parameters: {'n_estimators': 387, 'criterion': 'gini', 'min_samples_split': 6, 'min_samples_leaf': 9, 'max_features': None, 'max_leaf_nodes': 20, 'ccp_alpha': 0.025285645431092366}. Best is trial 63 with value: 0.5949376528550827.
# [I 2025-03-27 16:00:02,977] Trial 67 finished with value: 0.4774989379073501 and parameters: {'n_estimators': 411, 'criterion': 'gini', 'min_samples_split': 8, 'min_samples_leaf': 8, 'max_features': None, 'max_leaf_nodes': 23, 'ccp_alpha': 0.05853194624499547}. Best is trial 63 with value: 0.5949376528550827.
# [I 2025-03-27 16:00:24,845] Trial 68 finished with value: 0.5214208213113887 and parameters: {'n_estimators': 434, 'criterion': 'gini', 'min_samples_split': 5, 'min_samples_leaf': 9, 'max_features': None, 'max_leaf_nodes': 17, 'ccp_alpha': 0.049615989188926304}. Best is trial 63 with value: 0.5949376528550827.
# [I 2025-03-27 16:00:30,885] Trial 69 finished with value: 0.4493324097748691 and parameters: {'n_estimators': 396, 'criterion': 'gini', 'min_samples_split': 6, 'min_samples_leaf': 11, 'max_features': 'log2', 'max_leaf_nodes': 54, 'ccp_alpha': 0.035937590336898736}. Best is trial 63 with value: 0.5949376528550827.
# [I 2025-03-27 16:00:52,285] Trial 70 finished with value: 0.597919222288259 and parameters: {'n_estimators': 403, 'criterion': 'gini', 'min_samples_split': 7, 'min_samples_leaf': 7, 'max_features': None, 'max_leaf_nodes': 32, 'ccp_alpha': 0.016265075977339637}. Best is trial 70 with value: 0.597919222288259.
# [I 2025-03-27 16:01:12,050] Trial 71 finished with value: 0.5884627537059532 and parameters: {'n_estimators': 377, 'criterion': 'gini', 'min_samples_split': 7, 'min_samples_leaf': 7, 'max_features': None, 'max_leaf_nodes': 31, 'ccp_alpha': 0.015363070319288841}. Best is trial 70 with value: 0.597919222288259.
# [I 2025-03-27 16:01:34,089] Trial 72 finished with value: 0.5740700950036542 and parameters: {'n_estimators': 379, 'criterion': 'gini', 'min_samples_split': 7, 'min_samples_leaf': 5, 'max_features': None, 'max_leaf_nodes': 23, 'ccp_alpha': 0.013413058210014222}. Best is trial 70 with value: 0.597919222288259.
# [I 2025-03-27 16:01:56,433] Trial 73 finished with value: 0.6089263024643387 and parameters: {'n_estimators': 400, 'criterion': 'gini', 'min_samples_split': 9, 'min_samples_leaf': 7, 'max_features': None, 'max_leaf_nodes': 31, 'ccp_alpha': 0.01608947548092516}. Best is trial 73 with value: 0.6089263024643387.
# [I 2025-03-27 16:02:19,713] Trial 74 finished with value: 0.5811637404926474 and parameters: {'n_estimators': 403, 'criterion': 'gini', 'min_samples_split': 9, 'min_samples_leaf': 6, 'max_features': None, 'max_leaf_nodes': 31, 'ccp_alpha': 0.03209129136634966}. Best is trial 73 with value: 0.6089263024643387.
# [I 2025-03-27 16:02:39,967] Trial 75 finished with value: 0.586864461132263 and parameters: {'n_estimators': 362, 'criterion': 'gini', 'min_samples_split': 8, 'min_samples_leaf': 7, 'max_features': None, 'max_leaf_nodes': 26, 'ccp_alpha': 0.01476286196148786}. Best is trial 73 with value: 0.6089263024643387.
# [I 2025-03-27 16:03:00,779] Trial 76 finished with value: 0.5410117258687456 and parameters: {'n_estimators': 397, 'criterion': 'gini', 'min_samples_split': 7, 'min_samples_leaf': 6, 'max_features': None, 'max_leaf_nodes': 11, 'ccp_alpha': 0.04438807359502665}. Best is trial 73 with value: 0.6089263024643387.
# [I 2025-03-27 16:03:07,717] Trial 77 finished with value: 0.5308340961605229 and parameters: {'n_estimators': 377, 'criterion': 'gini', 'min_samples_split': 5, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'max_leaf_nodes': 14, 'ccp_alpha': 0.028687224210484686}. Best is trial 73 with value: 0.6089263024643387.
# [I 2025-03-27 16:03:32,427] Trial 78 finished with value: 0.2928136713042373 and parameters: {'n_estimators': 421, 'criterion': 'gini', 'min_samples_split': 10, 'min_samples_leaf': 6, 'max_features': None, 'max_leaf_nodes': 35, 'ccp_alpha': 0.09155903780514124}. Best is trial 73 with value: 0.6089263024643387.
# [I 2025-03-27 16:03:53,465] Trial 79 finished with value: 0.5650181344640003 and parameters: {'n_estimators': 406, 'criterion': 'gini', 'min_samples_split': 8, 'min_samples_leaf': 9, 'max_features': None, 'max_leaf_nodes': 18, 'ccp_alpha': 0.008898631968935238}. Best is trial 73 with value: 0.6089263024643387.
# [I 2025-03-27 16:04:14,232] Trial 80 finished with value: 0.2928136713042373 and parameters: {'n_estimators': 372, 'criterion': 'gini', 'min_samples_split': 9, 'min_samples_leaf': 7, 'max_features': None, 'max_leaf_nodes': 44, 'ccp_alpha': 0.1487353511039494}. Best is trial 73 with value: 0.6089263024643387.
# [I 2025-03-27 16:04:34,552] Trial 81 finished with value: 0.574227213102213 and parameters: {'n_estimators': 357, 'criterion': 'gini', 'min_samples_split': 7, 'min_samples_leaf': 7, 'max_features': None, 'max_leaf_nodes': 25, 'ccp_alpha': 0.017264133766960014}. Best is trial 73 with value: 0.6089263024643387.
# [I 2025-03-27 16:04:54,020] Trial 82 finished with value: 0.5830459324286051 and parameters: {'n_estimators': 361, 'criterion': 'gini', 'min_samples_split': 8, 'min_samples_leaf': 7, 'max_features': None, 'max_leaf_nodes': 28, 'ccp_alpha': 0.017440476862092574}. Best is trial 73 with value: 0.6089263024643387.
# [I 2025-03-27 16:05:14,325] Trial 83 finished with value: 0.5739551830632761 and parameters: {'n_estimators': 395, 'criterion': 'gini', 'min_samples_split': 5, 'min_samples_leaf': 8, 'max_features': None, 'max_leaf_nodes': 20, 'ccp_alpha': 0.02390890031251513}. Best is trial 73 with value: 0.6089263024643387.
# [I 2025-03-27 16:05:33,883] Trial 84 finished with value: 0.5766043300774981 and parameters: {'n_estimators': 367, 'criterion': 'gini', 'min_samples_split': 8, 'min_samples_leaf': 6, 'max_features': None, 'max_leaf_nodes': 15, 'ccp_alpha': 0.00800252290584642}. Best is trial 73 with value: 0.6089263024643387.
# [I 2025-03-27 16:05:54,805] Trial 85 finished with value: 0.557789989789484 and parameters: {'n_estimators': 414, 'criterion': 'gini', 'min_samples_split': 11, 'min_samples_leaf': 8, 'max_features': None, 'max_leaf_nodes': 32, 'ccp_alpha': 0.037904788162658985}. Best is trial 73 with value: 0.6089263024643387.
# [I 2025-03-27 16:06:15,691] Trial 86 finished with value: 0.5908028472801006 and parameters: {'n_estimators': 425, 'criterion': 'gini', 'min_samples_split': 9, 'min_samples_leaf': 9, 'max_features': None, 'max_leaf_nodes': 26, 'ccp_alpha': 0.013113612000198527}. Best is trial 73 with value: 0.6089263024643387.
# [I 2025-03-27 16:06:36,850] Trial 87 finished with value: 0.2928136713042373 and parameters: {'n_estimators': 428, 'criterion': 'gini', 'min_samples_split': 6, 'min_samples_leaf': 9, 'max_features': None, 'max_leaf_nodes': 55, 'ccp_alpha': 0.1266373361000121}. Best is trial 73 with value: 0.6089263024643387.
# [I 2025-03-27 16:06:44,572] Trial 88 finished with value: 0.5403679865695097 and parameters: {'n_estimators': 452, 'criterion': 'entropy', 'min_samples_split': 28, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_leaf_nodes': 22, 'ccp_alpha': 0.02828873053826783}. Best is trial 73 with value: 0.6089263024643387.
# [I 2025-03-27 16:07:03,443] Trial 89 finished with value: 0.574633396914696 and parameters: {'n_estimators': 391, 'criterion': 'gini', 'min_samples_split': 5, 'min_samples_leaf': 5, 'max_features': None, 'max_leaf_nodes': 9, 'ccp_alpha': 0.011101393983734841}. Best is trial 73 with value: 0.6089263024643387.
# [I 2025-03-27 16:07:25,371] Trial 90 finished with value: 0.58668818305883 and parameters: {'n_estimators': 425, 'criterion': 'gini', 'min_samples_split': 9, 'min_samples_leaf': 9, 'max_features': None, 'max_leaf_nodes': 47, 'ccp_alpha': 0.006396927496544556}. Best is trial 73 with value: 0.6089263024643387.
# [I 2025-03-27 16:07:47,304] Trial 91 finished with value: 0.5940560161321248 and parameters: {'n_estimators': 401, 'criterion': 'gini', 'min_samples_split': 7, 'min_samples_leaf': 8, 'max_features': None, 'max_leaf_nodes': 28, 'ccp_alpha': 0.014371027084355843}. Best is trial 73 with value: 0.6089263024643387.
# [I 2025-03-27 16:08:11,532] Trial 92 finished with value: 0.5818848643507587 and parameters: {'n_estimators': 441, 'criterion': 'gini', 'min_samples_split': 7, 'min_samples_leaf': 8, 'max_features': None, 'max_leaf_nodes': 35, 'ccp_alpha': 0.019791195129197015}. Best is trial 73 with value: 0.6089263024643387.
# [I 2025-03-27 16:08:35,449] Trial 93 finished with value: 0.5737926513509464 and parameters: {'n_estimators': 400, 'criterion': 'gini', 'min_samples_split': 6, 'min_samples_leaf': 6, 'max_features': None, 'max_leaf_nodes': 29, 'ccp_alpha': 0.015430874433850942}. Best is trial 73 with value: 0.6089263024643387.
# [I 2025-03-27 16:08:56,763] Trial 94 finished with value: 0.5799122995602145 and parameters: {'n_estimators': 388, 'criterion': 'gini', 'min_samples_split': 7, 'min_samples_leaf': 8, 'max_features': None, 'max_leaf_nodes': 25, 'ccp_alpha': 0.02489294419529897}. Best is trial 73 with value: 0.6089263024643387.
# [I 2025-03-27 16:09:04,213] Trial 95 finished with value: 0.49558282576799007 and parameters: {'n_estimators': 407, 'criterion': 'gini', 'min_samples_split': 10, 'min_samples_leaf': 9, 'max_features': 'sqrt', 'max_leaf_nodes': 39, 'ccp_alpha': 0.03290256191367128}. Best is trial 73 with value: 0.6089263024643387.
# [I 2025-03-27 16:09:24,698] Trial 96 finished with value: 0.5829493585047858 and parameters: {'n_estimators': 415, 'criterion': 'gini', 'min_samples_split': 9, 'min_samples_leaf': 10, 'max_features': None, 'max_leaf_nodes': 32, 'ccp_alpha': 0.003971182845721406}. Best is trial 73 with value: 0.6089263024643387.
# [I 2025-03-27 16:09:48,589] Trial 97 finished with value: 0.5895406639548234 and parameters: {'n_estimators': 449, 'criterion': 'gini', 'min_samples_split': 25, 'min_samples_leaf': 7, 'max_features': None, 'max_leaf_nodes': 75, 'ccp_alpha': 0.011353768852350827}. Best is trial 73 with value: 0.6089263024643387.
# [I 2025-03-27 16:10:14,247] Trial 98 finished with value: 0.5906174338113466 and parameters: {'n_estimators': 475, 'criterion': 'gini', 'min_samples_split': 26, 'min_samples_leaf': 7, 'max_features': None, 'max_leaf_nodes': 76, 'ccp_alpha': 0.011982559080912997}. Best is trial 73 with value: 0.6089263024643387.
# [I 2025-03-27 16:10:38,754] Trial 99 finished with value: 0.5894269088453871 and parameters: {'n_estimators': 482, 'criterion': 'gini', 'min_samples_split': 26, 'min_samples_leaf': 7, 'max_features': None, 'max_leaf_nodes': 75, 'ccp_alpha': 0.012357695120090951}. Best is trial 73 with value: 0.6089263024643387.
# Number of finished trials: 100
# Best trial: {'n_estimators': 400, 'criterion': 'gini', 'min_samples_split': 9, 'min_samples_leaf': 7, 'max_features': None, 'max_leaf_nodes': 31, 'ccp_alpha': 0.01608947548092516}

# %% [markdown]
# ## Model training

# %%
best_params = {'n_estimators': 400, 'criterion': 'gini', 'min_samples_split': 9,
 'min_samples_leaf': 7, 'max_features': None, 'max_leaf_nodes': 31,
 'ccp_alpha': 0.016,
'class_weight': {1: 1, 0: 1.5}} # 1 is Below median and 0 is Above median

# Train the final model with the best hyperparameters
#best_params = study.best_trial.params
SPRF = RandomForestClassifier(
    **best_params,
    random_state=42
)

# %%
X = all_data[watershed_attributes_50]  
y = all_data['kge_kappa_categories']
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# StratifiedKFold CV
skf = StratifiedKFold(n_splits=10, shuffle=True)
f1_scores = []
confusion_matrices = []

# Perform k-fold cross-validation
for train_index, test_index in skf.split(X, y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]
    
    SPRF.fit(X_train, y_train)
    y_pred = SPRF.predict(X_test)
        
    f1_scores.append(f1_score(y_test, y_pred, average='macro'))
    confusion_matrices.append(confusion_matrix(y_test, y_pred))
    

print(f'Cross-Validation F1 Scores: {f1_scores}')
print(f'Average F1 Score: {np.asarray(f1_scores).mean()}')
# Out:
# Cross-Validation F1 Scores: [0.6153846153846154, 0.6407894736842106, 0.6585858585858586, 0.7350543478260869, 0.7246376811594203, 0.8146341463414635, 0.7490829053558328, 0.680672268907563, 0.7368421052631579, 0.7490829053558328]
# Average F1 Score: 0.7104766307864041

# %%
SPRF.fit(X,y)
